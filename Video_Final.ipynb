# %%
import cv2
import numpy as np
from ultralytics import YOLO
import math

# Load the YOLO model
model = YOLO('yolov8x.pt')

# Open the video file
video_path = 'phil.mp4'  # Replace with your video file
cap = cv2.VideoCapture(video_path)

# Get video details
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Create a VideoWriter object to save the processed video
out = cv2.VideoWriter('output_video.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

while cap.isOpened():
    #Select one Frame from the video
    ret, frame = cap.read() # Read a frame from the video

    if not ret:
        break

    # Use YOLO to detect objects in the current frame
    results = model.predict(source=frame, save=False)

    # Access the detections in the results!
    detections = results[0]
    
    # For the detections in the one frame:
    for detection in detections.boxes:
        # Extract bounding box coordinates and class (what the object is)
        coords = detection.xyxy[0].cpu().numpy()  # Get bounding box (x1, y1, x2, y2)
        #x1,y1 is top left, x2,y2 is bottom right
        x1, y1, x2, y2 = map(int, coords)  # Convert to integers
        
        # Extract class and confidence
        class_id = int(detection.cls[0])  # Class ID
        confidence = detection.conf[0].item()  # Confidence score
    
        # Check if the class is 'person' (class_id == 0) and within the field of view of the court
        if class_id == 0 and x1 >= 175 and x2 <= 1050 and y1 >= 50:
            # Comparing the position of the bottom right corner of all detections 
            # This let's us know which players are on the near side vs the far side
            if y2 >= 280:
                # Draw bounding box and label on the image
                #cv2.rectangle(frame, (x1, y1), (x2, y2), color=(0, 255, 0), thickness=2)  # Green box for 'person'
                #label = f'Person: {confidence:.2f}'
                #Writing text on screen, location is above the top left of the box 
                #cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                
                #Gathering the center coordinates for each object detected
                center_x = (x1 + x2) // 2
                center_y = (y1 + y2) // 2
    
                # Draw's the center circle on the person (green team!)
                cv2.circle(frame, (center_x, center_y), radius=5, color=(0, 255, 0), thickness=-1)  # Green circle
    
                #Putting on mini court!
                #Relative to the big court, finding x and y:
                #We use 369,150 since that's the top left of the big court
                x_rel = center_x - 369
                y_rel = center_y - 150
    
                #Scale
                x_scaled = x_rel * 0.4
                y_scaled = y_rel * 0.4
    
                
                #Manual adjusts added to the scaled values
                final_x = 950 + x_scaled
                final_y = 480 + y_scaled
    
            
    
                cv2.circle(frame, (int(final_x), int(final_y)), radius=5, color=(0, 255, 0), thickness=-1)  # Blue point with radius 5
    
            ##579, 300 for drost!
    
                #Big Court 0 = 700 small court (x)
            #Max X is 900, Max Y is 500.9
                #Big Court 0 = 300 small court (y)
    
                
            
            else:
                # Draw bounding box and label on the image
                #cv2.rectangle(frame, (x1, y1), (x2, y2), color=(255, 0, 0), thickness=2)  # Blue box for 'person'
                #label = f'Person: {confidence:.2f}'
                #cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)
                center_x = (x1 + x2) // 2
                center_y = (y1 + y2) // 2
    
                # Draw's the center circle on the person (green team!)
                cv2.circle(frame, (center_x, center_y), radius=5, color=(255, 0, 0), thickness=-1)  # Blue circle
    
                
    
                #Putting on mini court!
                #Relative to the big court, finding x and y:
                x_rel = center_x - 369
                y_rel = center_y - 150
    
                #Scale
                x_scaled = x_rel * 0.4
                y_scaled = y_rel * 0.4
    
                
                #THese were 700,300 but moved around manually
                final_x = 950 + x_scaled
                final_y = 465 + y_scaled
    
            
    
                cv2.circle(frame, (int(final_x), int(final_y)), radius=5, color=(255, 0, 0), thickness=-1)  # Blue point with radius 5

        # Get image dimensions
        height, width, _ = frame.shape
        
        # Draw vertical lines at different width intervals
        #for x in range(0, width, 50):  # 100-pixel intervals
            #Lines
            #cv2.line(frame, (x, 0), (x, height), (0, 255, 0), 2)  # Green vertical lines
            #Actual Numbers
        #cv2.putText(frame, f'X={x}', (x, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
        
        # Draw horizontal lines at different height intervals
        #for y in range(0, height, 50):  # 100-pixel intervals
            #Lines
            #cv2.line(frame, (0, y), (width, y), (255, 0, 0), 2)  # Blue horizontal lines
            #Actual Numbers
            #cv2.putText(frame, f'Y={y}', (10, y + 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)
            
        ##Court Outline
        
        #Bottom Left
        #cv2.circle(frame, (20, 710), radius=5, color=(0, 0, 255), thickness=-1)  # Red point with radius 5
        
        #Bottom Right
        #cv2.circle(frame, (1270, 710), radius=5, color=(0, 0, 255), thickness=-1)  # Red point with radius 5
        
        #Top Left 
        #cv2.circle(frame, (369, 150), radius=5, color=(0, 0, 255), thickness=-1)  # Red point with radius 5
        
        #Top Right
        #cv2.circle(frame, (820, 150), radius=5, color=(0, 0, 255), thickness=-1)  # Red point with radius 5
        
        #Lines
        
        # Bottom Left to Bottom Right
        #cv2.line(frame, (20, 710), (1270, 710), color=(0, 255, 0), thickness=2)  # Green line
        
        # Bottom Right to Top Right
        #cv2.line(frame, (1270, 710), (820, 150), color=(0, 255, 0), thickness=2)  # Green line
        
        # Top Right to Top Left
        #cv2.line(frame, (820, 150), (369, 150), color=(0, 255, 0), thickness=2)  # Green line
        
        # Top Left to Bottom Left
        #cv2.line(frame, (369, 150), (20, 710), color=(0, 255, 0), thickness=2)  # Green line
        
        
    
        
        #Let's build a mini court!!!
        
        #First start with coordinates like we did to map out the court:
        
        #Let's also find the "distance"
        
        #Bottom Left to Bottom Right
        bl_br = math.hypot(20 - 1270, 710 - 710)
        
        #Bottom Left to Top Left
        bl_tl = math.hypot(20 - 10, 710 - 150)
        
        #Bottom Right to Top Right
        br_tr = math.hypot(1270 - 820, 710 - 150)
        
        #Top Left to Top Right
        tl_tr = math.hypot(369 - 820, 100 - 100)
        
        #Start Mini Court
        
        mini_top_left_x = 950
        mini_top_left_y = 450
        x_scale_factor = 0.45
        y_scale_factor = 0.4
        
        scaled_bl_br = bl_br * x_scale_factor  # Scale horizontal bottom-left to bottom-right
        scaled_bl_tl = bl_tl * y_scale_factor  # Scale diagonal bottom-left to top-left
        scaled_br_tr = br_tr * y_scale_factor  # Scale diagonal bottom-right to top-right
        scaled_tl_tr = tl_tr * x_scale_factor  # Scale horizontal top-left to top-right
        
        top = mini_top_left_x + scaled_tl_tr 
        left = mini_top_left_y + scaled_bl_tl
        
        #Top Line for mini court
        cv2.line(frame,(mini_top_left_x ,mini_top_left_y), (int(top),mini_top_left_y), color = (0,0,255), thickness=2)
        
        #Left Line for mini court
        cv2.line(frame,(mini_top_left_x ,mini_top_left_y), (mini_top_left_x-100,int(left)), color = (0,0,255), thickness=2)
        
        #Bottom Line
        cv2.line(frame,(mini_top_left_x-100,int(left)), (int(top+100),int(left)), color = (0,0,255), thickness=2)
        
        #Right Line
        cv2.line(frame,(int(top),mini_top_left_y), (int(top+100),int(left)), color = (0,0,255), thickness=2)
        
        #Net!
        cv2.line(frame,(925,505), (int(top+20),505), color = (0,0,255), thickness=2)

        
# Write the processed frame to the output video
    out.write(frame)

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print("Video processing completed. Check 'output_video.mp4'")
# Out:
# 0: 384x640 10 persons, 6 umbrellas, 389.6ms
# Speed: 6.9ms preprocess, 389.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 umbrellas, 1 sports ball, 379.2ms
# Speed: 1.0ms preprocess, 379.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 umbrellas, 1 sports ball, 365.7ms
# Speed: 1.0ms preprocess, 365.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 357.0ms
# Speed: 1.2ms preprocess, 357.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 umbrellas, 361.1ms
# Speed: 1.1ms preprocess, 361.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 umbrellas, 1 banana, 363.2ms
# Speed: 1.5ms preprocess, 363.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 1 sports ball, 360.3ms
# Speed: 1.0ms preprocess, 360.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 2 sports balls, 354.8ms
# Speed: 0.9ms preprocess, 354.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 352.2ms
# Speed: 1.1ms preprocess, 352.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 368.9ms
# Speed: 1.0ms preprocess, 368.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 358.3ms
# Speed: 1.1ms preprocess, 358.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 umbrellas, 358.7ms
# Speed: 0.9ms preprocess, 358.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 364.1ms
# Speed: 1.7ms preprocess, 364.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 umbrellas, 355.6ms
# Speed: 1.1ms preprocess, 355.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 umbrellas, 354.4ms
# Speed: 1.1ms preprocess, 354.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 365.1ms
# Speed: 1.2ms preprocess, 365.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 356.1ms
# Speed: 1.4ms preprocess, 356.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 352.6ms
# Speed: 1.1ms preprocess, 352.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 umbrellas, 362.9ms
# Speed: 0.9ms preprocess, 362.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 umbrellas, 354.2ms
# Speed: 1.0ms preprocess, 354.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 umbrellas, 367.2ms
# Speed: 1.2ms preprocess, 367.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 358.0ms
# Speed: 1.1ms preprocess, 358.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 umbrellas, 360.9ms
# Speed: 1.1ms preprocess, 360.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 umbrellas, 369.4ms
# Speed: 1.1ms preprocess, 369.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 umbrellas, 355.2ms
# Speed: 1.0ms preprocess, 355.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 umbrellas, 357.3ms
# Speed: 1.3ms preprocess, 357.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 1 skateboard, 362.0ms
# Speed: 1.0ms preprocess, 362.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 umbrellas, 354.9ms
# Speed: 1.0ms preprocess, 354.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 umbrellas, 455.4ms
# Speed: 1.0ms preprocess, 455.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 umbrellas, 364.2ms
# Speed: 1.4ms preprocess, 364.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 356.2ms
# Speed: 1.0ms preprocess, 356.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 353.0ms
# Speed: 1.0ms preprocess, 353.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 364.6ms
# Speed: 1.4ms preprocess, 364.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 360.9ms
# Speed: 1.0ms preprocess, 360.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 371.5ms
# Speed: 1.1ms preprocess, 371.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 366.9ms
# Speed: 1.1ms preprocess, 366.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 356.1ms
# Speed: 0.9ms preprocess, 356.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 364.2ms
# Speed: 1.2ms preprocess, 364.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 356.2ms
# Speed: 0.9ms preprocess, 356.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 353.8ms
# Speed: 0.9ms preprocess, 353.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 359.5ms
# Speed: 1.0ms preprocess, 359.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 357.8ms
# Speed: 0.9ms preprocess, 357.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 355.5ms
# Speed: 1.0ms preprocess, 355.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 363.8ms
# Speed: 0.9ms preprocess, 363.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 362.6ms
# Speed: 1.0ms preprocess, 362.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 355.0ms
# Speed: 1.0ms preprocess, 355.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 dog, 5 umbrellas, 360.8ms
# Speed: 0.9ms preprocess, 360.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 352.2ms
# Speed: 1.0ms preprocess, 352.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 358.8ms
# Speed: 0.9ms preprocess, 358.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 360.6ms
# Speed: 0.9ms preprocess, 360.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 357.4ms
# Speed: 1.0ms preprocess, 357.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 359.5ms
# Speed: 1.0ms preprocess, 359.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 358.4ms
# Speed: 1.2ms preprocess, 358.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 umbrellas, 355.3ms
# Speed: 1.0ms preprocess, 355.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 umbrellas, 363.9ms
# Speed: 1.0ms preprocess, 363.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 357.6ms
# Speed: 0.9ms preprocess, 357.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 1 skateboard, 495.5ms
# Speed: 1.0ms preprocess, 495.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 1 skateboard, 363.8ms
# Speed: 1.0ms preprocess, 363.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 1 skateboard, 353.9ms
# Speed: 0.9ms preprocess, 353.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 357.3ms
# Speed: 0.9ms preprocess, 357.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 361.8ms
# Speed: 1.0ms preprocess, 361.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 dog, 3 umbrellas, 357.3ms
# Speed: 1.0ms preprocess, 357.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 dog, 4 umbrellas, 357.6ms
# Speed: 1.0ms preprocess, 357.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 dog, 3 umbrellas, 355.7ms
# Speed: 1.0ms preprocess, 355.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 dog, 4 umbrellas, 356.6ms
# Speed: 1.0ms preprocess, 356.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 dog, 3 umbrellas, 363.3ms
# Speed: 0.9ms preprocess, 363.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 dog, 4 umbrellas, 354.7ms
# Speed: 1.1ms preprocess, 354.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 umbrellas, 357.0ms
# Speed: 1.0ms preprocess, 357.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 umbrellas, 364.2ms
# Speed: 1.0ms preprocess, 364.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 umbrellas, 360.9ms
# Speed: 1.0ms preprocess, 360.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 3 umbrellas, 367.0ms
# Speed: 1.0ms preprocess, 367.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 umbrellas, 362.2ms
# Speed: 1.0ms preprocess, 362.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 umbrellas, 1 skateboard, 413.3ms
# Speed: 1.0ms preprocess, 413.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 359.7ms
# Speed: 0.9ms preprocess, 359.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 363.9ms
# Speed: 0.9ms preprocess, 363.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 umbrellas, 359.4ms
# Speed: 1.0ms preprocess, 359.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 umbrellas, 377.6ms
# Speed: 0.9ms preprocess, 377.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 umbrellas, 363.1ms
# Speed: 1.0ms preprocess, 363.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 umbrellas, 361.1ms
# Speed: 0.9ms preprocess, 361.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 3 umbrellas, 389.1ms
# Speed: 1.0ms preprocess, 389.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 3 umbrellas, 358.4ms
# Speed: 0.9ms preprocess, 358.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 umbrellas, 358.9ms
# Speed: 1.0ms preprocess, 358.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 umbrellas, 363.8ms
# Speed: 1.0ms preprocess, 363.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 umbrellas, 359.5ms
# Speed: 0.9ms preprocess, 359.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 358.4ms
# Speed: 0.9ms preprocess, 358.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 362.9ms
# Speed: 1.0ms preprocess, 362.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 umbrellas, 359.7ms
# Speed: 0.9ms preprocess, 359.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 363.1ms
# Speed: 1.0ms preprocess, 363.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 umbrellas, 363.7ms
# Speed: 1.0ms preprocess, 363.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 358.8ms
# Speed: 0.9ms preprocess, 358.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 357.2ms
# Speed: 0.9ms preprocess, 357.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 359.8ms
# Speed: 1.0ms preprocess, 359.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 357.9ms
# Speed: 0.9ms preprocess, 357.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 360.8ms
# Speed: 1.0ms preprocess, 360.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 umbrellas, 359.5ms
# Speed: 1.0ms preprocess, 359.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 dog, 5 umbrellas, 357.4ms
# Speed: 0.9ms preprocess, 357.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 367.4ms
# Speed: 1.1ms preprocess, 367.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 356.6ms
# Speed: 1.0ms preprocess, 356.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 355.9ms
# Speed: 0.9ms preprocess, 355.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 363.9ms
# Speed: 1.0ms preprocess, 363.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 364.9ms
# Speed: 1.0ms preprocess, 364.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 359.7ms
# Speed: 0.9ms preprocess, 359.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 363.7ms
# Speed: 1.0ms preprocess, 363.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 3 umbrellas, 422.9ms
# Speed: 0.9ms preprocess, 422.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 umbrellas, 361.2ms
# Speed: 1.2ms preprocess, 361.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 umbrellas, 1 skateboard, 359.9ms
# Speed: 1.1ms preprocess, 359.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 1 skateboard, 354.8ms
# Speed: 1.0ms preprocess, 354.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 364.7ms
# Speed: 1.0ms preprocess, 364.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 357.0ms
# Speed: 1.0ms preprocess, 357.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 354.6ms
# Speed: 0.8ms preprocess, 354.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 363.3ms
# Speed: 0.9ms preprocess, 363.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 359.6ms
# Speed: 1.0ms preprocess, 359.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 353.6ms
# Speed: 0.9ms preprocess, 353.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 366.0ms
# Speed: 0.9ms preprocess, 366.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 360.6ms
# Speed: 1.0ms preprocess, 360.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 357.8ms
# Speed: 0.9ms preprocess, 357.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 366.8ms
# Speed: 0.9ms preprocess, 366.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 356.6ms
# Speed: 1.2ms preprocess, 356.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 357.2ms
# Speed: 0.9ms preprocess, 357.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 364.2ms
# Speed: 1.0ms preprocess, 364.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 358.0ms
# Speed: 0.9ms preprocess, 358.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 361.2ms
# Speed: 1.0ms preprocess, 361.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 353.8ms
# Speed: 1.0ms preprocess, 353.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 360.7ms
# Speed: 0.9ms preprocess, 360.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 362.4ms
# Speed: 0.9ms preprocess, 362.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 358.6ms
# Speed: 0.9ms preprocess, 358.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 353.2ms
# Speed: 1.1ms preprocess, 353.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 362.0ms
# Speed: 0.9ms preprocess, 362.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 355.7ms
# Speed: 0.9ms preprocess, 355.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 362.8ms
# Speed: 0.9ms preprocess, 362.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 367.1ms
# Speed: 1.0ms preprocess, 367.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 1 frisbee, 357.3ms
# Speed: 0.9ms preprocess, 357.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 1 frisbee, 360.3ms
# Speed: 0.9ms preprocess, 360.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 1 frisbee, 365.8ms
# Speed: 0.9ms preprocess, 365.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 1 frisbee, 414.5ms
# Speed: 1.0ms preprocess, 414.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 357.4ms
# Speed: 0.9ms preprocess, 357.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 368.0ms
# Speed: 1.0ms preprocess, 368.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 359.5ms
# Speed: 0.9ms preprocess, 359.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 362.5ms
# Speed: 0.9ms preprocess, 362.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 355.4ms
# Speed: 0.9ms preprocess, 355.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 358.0ms
# Speed: 0.9ms preprocess, 358.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 umbrellas, 363.5ms
# Speed: 1.0ms preprocess, 363.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 358.2ms
# Speed: 0.9ms preprocess, 358.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 359.4ms
# Speed: 0.9ms preprocess, 359.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 365.2ms
# Speed: 0.8ms preprocess, 365.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 354.4ms
# Speed: 0.9ms preprocess, 354.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 354.3ms
# Speed: 1.3ms preprocess, 354.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 364.6ms
# Speed: 1.4ms preprocess, 364.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 358.4ms
# Speed: 1.0ms preprocess, 358.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 357.1ms
# Speed: 0.9ms preprocess, 357.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 7 umbrellas, 1 skateboard, 363.6ms
# Speed: 1.0ms preprocess, 363.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 1 sports ball, 357.8ms
# Speed: 0.9ms preprocess, 357.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 1 frisbee, 360.3ms
# Speed: 0.9ms preprocess, 360.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 1 frisbee, 360.7ms
# Speed: 1.0ms preprocess, 360.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 359.5ms
# Speed: 1.0ms preprocess, 359.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 umbrellas, 1 sports ball, 361.7ms
# Speed: 1.0ms preprocess, 361.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 354.1ms
# Speed: 0.9ms preprocess, 354.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 358.2ms
# Speed: 1.0ms preprocess, 358.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 1 sports ball, 361.5ms
# Speed: 1.0ms preprocess, 361.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 358.0ms
# Speed: 1.0ms preprocess, 358.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 358.6ms
# Speed: 1.0ms preprocess, 358.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 369.4ms
# Speed: 1.5ms preprocess, 369.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 355.0ms
# Speed: 0.9ms preprocess, 355.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 356.5ms
# Speed: 0.9ms preprocess, 356.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 425.1ms
# Speed: 1.0ms preprocess, 425.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 1 skateboard, 358.1ms
# Speed: 0.9ms preprocess, 358.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 362.5ms
# Speed: 1.0ms preprocess, 362.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 359.4ms
# Speed: 1.0ms preprocess, 359.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 357.4ms
# Speed: 0.9ms preprocess, 357.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 360.7ms
# Speed: 1.1ms preprocess, 360.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 356.6ms
# Speed: 0.9ms preprocess, 356.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 366.9ms
# Speed: 1.0ms preprocess, 366.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 7 umbrellas, 368.5ms
# Speed: 0.9ms preprocess, 368.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 390.5ms
# Speed: 0.9ms preprocess, 390.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 6 umbrellas, 364.0ms
# Speed: 0.9ms preprocess, 364.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 dog, 7 umbrellas, 366.4ms
# Speed: 1.3ms preprocess, 366.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 dog, 6 umbrellas, 358.5ms
# Speed: 1.0ms preprocess, 358.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 360.1ms
# Speed: 0.9ms preprocess, 360.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 dog, 6 umbrellas, 383.4ms
# Speed: 0.9ms preprocess, 383.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 358.7ms
# Speed: 1.0ms preprocess, 358.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 438.3ms
# Speed: 0.9ms preprocess, 438.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 365.8ms
# Speed: 1.0ms preprocess, 365.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 358.6ms
# Speed: 1.3ms preprocess, 358.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 369.1ms
# Speed: 1.0ms preprocess, 369.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 363.5ms
# Speed: 0.9ms preprocess, 363.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 370.6ms
# Speed: 0.9ms preprocess, 370.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 7 umbrellas, 382.3ms
# Speed: 1.1ms preprocess, 382.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 356.3ms
# Speed: 0.9ms preprocess, 356.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 364.1ms
# Speed: 1.2ms preprocess, 364.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 366.8ms
# Speed: 0.9ms preprocess, 366.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 359.0ms
# Speed: 0.9ms preprocess, 359.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 1 dog, 7 umbrellas, 364.0ms
# Speed: 0.8ms preprocess, 364.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 358.9ms
# Speed: 0.9ms preprocess, 358.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 362.5ms
# Speed: 0.9ms preprocess, 362.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 451.8ms
# Speed: 0.9ms preprocess, 451.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 356.0ms
# Speed: 1.0ms preprocess, 356.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 358.2ms
# Speed: 1.0ms preprocess, 358.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 umbrellas, 366.6ms
# Speed: 1.0ms preprocess, 366.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 umbrellas, 355.5ms
# Speed: 1.1ms preprocess, 355.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 374.3ms
# Speed: 0.9ms preprocess, 374.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 umbrellas, 360.9ms
# Speed: 1.0ms preprocess, 360.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 8 umbrellas, 358.4ms
# Speed: 1.1ms preprocess, 358.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 8 umbrellas, 356.4ms
# Speed: 0.9ms preprocess, 356.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 363.2ms
# Speed: 1.0ms preprocess, 363.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 364.5ms
# Speed: 1.0ms preprocess, 364.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 365.1ms
# Speed: 1.0ms preprocess, 365.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 361.8ms
# Speed: 0.9ms preprocess, 361.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 358.3ms
# Speed: 0.9ms preprocess, 358.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 umbrellas, 363.7ms
# Speed: 0.9ms preprocess, 363.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 umbrellas, 353.0ms
# Speed: 1.2ms preprocess, 353.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 umbrellas, 361.5ms
# Speed: 0.9ms preprocess, 361.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 362.6ms
# Speed: 0.9ms preprocess, 362.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 356.6ms
# Speed: 1.3ms preprocess, 356.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 356.8ms
# Speed: 0.9ms preprocess, 356.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 365.5ms
# Speed: 0.9ms preprocess, 365.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 353.8ms
# Speed: 1.0ms preprocess, 353.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 368.0ms
# Speed: 0.9ms preprocess, 368.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 366.3ms
# Speed: 0.9ms preprocess, 366.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 1 skateboard, 355.4ms
# Speed: 0.8ms preprocess, 355.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 357.7ms
# Speed: 1.1ms preprocess, 357.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 umbrellas, 360.5ms
# Speed: 1.0ms preprocess, 360.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 umbrellas, 363.1ms
# Speed: 0.9ms preprocess, 363.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 2 umbrellas, 1 skateboard, 423.6ms
# Speed: 1.0ms preprocess, 423.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 umbrellas, 357.0ms
# Speed: 1.3ms preprocess, 357.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 umbrellas, 357.1ms
# Speed: 1.1ms preprocess, 357.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 umbrellas, 365.2ms
# Speed: 0.9ms preprocess, 365.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 umbrellas, 357.6ms
# Speed: 1.0ms preprocess, 357.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 umbrellas, 1 skis, 354.8ms
# Speed: 1.0ms preprocess, 354.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 umbrellas, 406.9ms
# Speed: 1.0ms preprocess, 406.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 362.0ms
# Speed: 0.9ms preprocess, 362.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 356.8ms
# Speed: 0.9ms preprocess, 356.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 379.5ms
# Speed: 1.1ms preprocess, 379.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 361.2ms
# Speed: 0.9ms preprocess, 361.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 366.0ms
# Speed: 1.0ms preprocess, 366.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 365.4ms
# Speed: 1.0ms preprocess, 365.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 357.1ms
# Speed: 1.0ms preprocess, 357.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 372.4ms
# Speed: 1.0ms preprocess, 372.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 395.8ms
# Speed: 1.0ms preprocess, 395.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 358.7ms
# Speed: 1.0ms preprocess, 358.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 umbrellas, 370.2ms
# Speed: 0.9ms preprocess, 370.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 357.8ms
# Speed: 1.0ms preprocess, 357.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 357.5ms
# Speed: 1.0ms preprocess, 357.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 369.0ms
# Speed: 0.9ms preprocess, 369.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 358.7ms
# Speed: 1.4ms preprocess, 358.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 366.3ms
# Speed: 0.9ms preprocess, 366.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 362.1ms
# Speed: 1.0ms preprocess, 362.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 3 umbrellas, 360.0ms
# Speed: 1.0ms preprocess, 360.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 392.9ms
# Speed: 1.0ms preprocess, 392.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 umbrellas, 377.7ms
# Speed: 1.1ms preprocess, 377.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 umbrellas, 371.9ms
# Speed: 1.0ms preprocess, 371.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 378.7ms
# Speed: 0.9ms preprocess, 378.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 479.7ms
# Speed: 0.9ms preprocess, 479.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 402.7ms
# Speed: 0.9ms preprocess, 402.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 umbrellas, 372.0ms
# Speed: 0.9ms preprocess, 372.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 umbrellas, 360.9ms
# Speed: 1.0ms preprocess, 360.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 umbrellas, 369.3ms
# Speed: 1.0ms preprocess, 369.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 3 umbrellas, 363.7ms
# Speed: 1.0ms preprocess, 363.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 360.4ms
# Speed: 1.0ms preprocess, 360.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 1 sports ball, 366.5ms
# Speed: 0.9ms preprocess, 366.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 367.0ms
# Speed: 1.0ms preprocess, 367.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 360.1ms
# Speed: 1.0ms preprocess, 360.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 369.3ms
# Speed: 1.2ms preprocess, 369.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 3 umbrellas, 361.1ms
# Speed: 0.9ms preprocess, 361.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 369.0ms
# Speed: 1.0ms preprocess, 369.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 366.8ms
# Speed: 1.0ms preprocess, 366.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 359.6ms
# Speed: 1.1ms preprocess, 359.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 364.8ms
# Speed: 1.0ms preprocess, 364.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 362.6ms
# Speed: 0.9ms preprocess, 362.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 375.5ms
# Speed: 0.9ms preprocess, 375.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 367.6ms
# Speed: 0.9ms preprocess, 367.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 359.3ms
# Speed: 0.9ms preprocess, 359.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 364.2ms
# Speed: 1.0ms preprocess, 364.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 371.1ms
# Speed: 0.9ms preprocess, 371.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 360.2ms
# Speed: 1.0ms preprocess, 360.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 359.1ms
# Speed: 1.0ms preprocess, 359.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 368.8ms
# Speed: 1.3ms preprocess, 368.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 umbrellas, 358.7ms
# Speed: 1.1ms preprocess, 358.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 umbrellas, 358.4ms
# Speed: 1.0ms preprocess, 358.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 3 umbrellas, 363.1ms
# Speed: 1.0ms preprocess, 363.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 362.5ms
# Speed: 1.0ms preprocess, 362.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 4 umbrellas, 368.0ms
# Speed: 1.0ms preprocess, 368.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 430.9ms
# Speed: 1.0ms preprocess, 430.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 361.0ms
# Speed: 1.0ms preprocess, 361.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 5 umbrellas, 368.8ms
# Speed: 1.0ms preprocess, 368.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 361.3ms
# Speed: 1.0ms preprocess, 361.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 359.6ms
# Speed: 1.0ms preprocess, 359.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 370.0ms
# Speed: 1.0ms preprocess, 370.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 9 umbrellas, 361.8ms
# Speed: 0.9ms preprocess, 361.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 umbrellas, 366.4ms
# Speed: 1.0ms preprocess, 366.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 9 umbrellas, 361.7ms
# Speed: 1.1ms preprocess, 361.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 8 umbrellas, 369.0ms
# Speed: 1.1ms preprocess, 369.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 7 umbrellas, 369.5ms
# Speed: 1.0ms preprocess, 369.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 6 umbrellas, 364.4ms
# Speed: 1.0ms preprocess, 364.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 8 umbrellas, 362.4ms
# Speed: 1.0ms preprocess, 362.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 9 umbrellas, 369.8ms
# Speed: 1.0ms preprocess, 369.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 9 umbrellas, 372.5ms
# Speed: 1.0ms preprocess, 372.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 umbrellas, 366.9ms
# Speed: 1.0ms preprocess, 366.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 8 umbrellas, 369.2ms
# Speed: 1.0ms preprocess, 369.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 8 umbrellas, 366.4ms
# Speed: 1.0ms preprocess, 366.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 8 umbrellas, 363.5ms
# Speed: 1.0ms preprocess, 363.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 367.0ms
# Speed: 0.9ms preprocess, 367.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 362.3ms
# Speed: 1.0ms preprocess, 362.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 367.6ms
# Speed: 1.0ms preprocess, 367.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 1 baseball glove, 364.6ms
# Speed: 1.0ms preprocess, 364.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 365.6ms
# Speed: 1.0ms preprocess, 365.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 5 umbrellas, 370.7ms
# Speed: 1.0ms preprocess, 370.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 361.8ms
# Speed: 1.0ms preprocess, 361.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 362.7ms
# Speed: 1.0ms preprocess, 362.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 428.6ms
# Speed: 1.1ms preprocess, 428.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 4 umbrellas, 364.3ms
# Speed: 1.0ms preprocess, 364.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 361.6ms
# Speed: 1.0ms preprocess, 361.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 367.8ms
# Speed: 1.1ms preprocess, 367.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 5 umbrellas, 366.9ms
# Speed: 1.0ms preprocess, 366.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 370.7ms
# Speed: 1.0ms preprocess, 370.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 363.3ms
# Speed: 1.0ms preprocess, 363.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 363.2ms
# Speed: 1.0ms preprocess, 363.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 372.4ms
# Speed: 1.0ms preprocess, 372.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 362.0ms
# Speed: 1.0ms preprocess, 362.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 364.1ms
# Speed: 1.0ms preprocess, 364.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 umbrellas, 369.0ms
# Speed: 1.0ms preprocess, 369.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 364.3ms
# Speed: 1.5ms preprocess, 364.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 363.5ms
# Speed: 1.0ms preprocess, 363.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 367.0ms
# Speed: 1.0ms preprocess, 367.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 362.3ms
# Speed: 1.0ms preprocess, 362.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 umbrellas, 368.4ms
# Speed: 1.2ms preprocess, 368.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 umbrellas, 377.1ms
# Speed: 1.1ms preprocess, 377.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 umbrellas, 366.9ms
# Speed: 1.0ms preprocess, 366.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 umbrellas, 369.1ms
# Speed: 1.1ms preprocess, 369.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 9 umbrellas, 361.7ms
# Speed: 1.0ms preprocess, 361.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 9 umbrellas, 360.2ms
# Speed: 1.0ms preprocess, 360.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 11 umbrellas, 367.8ms
# Speed: 1.0ms preprocess, 367.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 11 umbrellas, 362.8ms
# Speed: 1.1ms preprocess, 362.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 11 umbrellas, 362.9ms
# Speed: 1.1ms preprocess, 362.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 11 umbrellas, 429.1ms
# Speed: 1.0ms preprocess, 429.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 umbrellas, 359.9ms
# Speed: 1.0ms preprocess, 359.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 11 umbrellas, 362.4ms
# Speed: 1.0ms preprocess, 362.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 11 umbrellas, 363.7ms
# Speed: 1.1ms preprocess, 363.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 umbrellas, 358.4ms
# Speed: 1.0ms preprocess, 358.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 dog, 7 umbrellas, 367.0ms
# Speed: 1.0ms preprocess, 367.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 umbrellas, 377.6ms
# Speed: 1.0ms preprocess, 377.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 umbrellas, 359.2ms
# Speed: 1.0ms preprocess, 359.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 umbrellas, 372.7ms
# Speed: 1.0ms preprocess, 372.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 6 umbrellas, 364.3ms
# Speed: 1.0ms preprocess, 364.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 car, 7 umbrellas, 366.9ms
# Speed: 1.0ms preprocess, 366.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 1 car, 6 umbrellas, 371.7ms
# Speed: 1.0ms preprocess, 371.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 8 umbrellas, 362.2ms
# Speed: 1.0ms preprocess, 362.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 361.4ms
# Speed: 1.0ms preprocess, 361.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 367.4ms
# Speed: 1.1ms preprocess, 367.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 umbrellas, 364.1ms
# Speed: 0.9ms preprocess, 364.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 9 umbrellas, 368.9ms
# Speed: 1.0ms preprocess, 368.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 365.6ms
# Speed: 1.1ms preprocess, 365.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 363.1ms
# Speed: 1.0ms preprocess, 363.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 373.6ms
# Speed: 1.0ms preprocess, 373.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 380.9ms
# Speed: 1.0ms preprocess, 380.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 364.2ms
# Speed: 1.0ms preprocess, 364.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 380.3ms
# Speed: 1.0ms preprocess, 380.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 438.8ms
# Speed: 1.0ms preprocess, 438.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 368.9ms
# Speed: 1.0ms preprocess, 368.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 4 umbrellas, 363.4ms
# Speed: 1.4ms preprocess, 363.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 363.1ms
# Speed: 1.0ms preprocess, 363.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 4 umbrellas, 370.8ms
# Speed: 1.0ms preprocess, 370.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 365.4ms
# Speed: 1.0ms preprocess, 365.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 5 umbrellas, 400.5ms
# Speed: 1.1ms preprocess, 400.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 448.0ms
# Speed: 1.0ms preprocess, 448.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 umbrellas, 367.6ms
# Speed: 1.0ms preprocess, 367.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 umbrellas, 360.5ms
# Speed: 1.0ms preprocess, 360.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 umbrellas, 367.7ms
# Speed: 1.0ms preprocess, 367.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 361.9ms
# Speed: 1.0ms preprocess, 361.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 375.7ms
# Speed: 1.0ms preprocess, 375.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 366.1ms
# Speed: 1.0ms preprocess, 366.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 360.1ms
# Speed: 1.0ms preprocess, 360.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 370.7ms
# Speed: 1.0ms preprocess, 370.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 umbrellas, 359.1ms
# Speed: 1.0ms preprocess, 359.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 380.3ms
# Speed: 1.0ms preprocess, 380.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 380.4ms
# Speed: 1.0ms preprocess, 380.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 362.7ms
# Speed: 1.0ms preprocess, 362.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 362.3ms
# Speed: 1.0ms preprocess, 362.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 7 umbrellas, 366.5ms
# Speed: 1.0ms preprocess, 366.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 7 umbrellas, 447.0ms
# Speed: 1.0ms preprocess, 447.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 377.6ms
# Speed: 0.9ms preprocess, 377.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 6 umbrellas, 363.3ms
# Speed: 1.0ms preprocess, 363.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 368.9ms
# Speed: 1.0ms preprocess, 368.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 umbrellas, 369.8ms
# Speed: 1.0ms preprocess, 369.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 362.9ms
# Speed: 1.0ms preprocess, 362.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 364.2ms
# Speed: 1.1ms preprocess, 364.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 umbrellas, 367.0ms
# Speed: 1.0ms preprocess, 367.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 5 umbrellas, 367.9ms
# Speed: 1.0ms preprocess, 367.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 3 umbrellas, 368.0ms
# Speed: 0.9ms preprocess, 368.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 10 umbrellas, 363.0ms
# Speed: 1.1ms preprocess, 363.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 umbrellas, 366.1ms
# Speed: 1.1ms preprocess, 366.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 umbrellas, 367.3ms
# Speed: 1.0ms preprocess, 367.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 361.7ms
# Speed: 1.3ms preprocess, 361.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 361.4ms
# Speed: 1.0ms preprocess, 361.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 umbrellas, 371.5ms
# Speed: 1.3ms preprocess, 371.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 umbrellas, 372.0ms
# Speed: 1.0ms preprocess, 372.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 11 umbrellas, 1 frisbee, 369.3ms
# Speed: 1.0ms preprocess, 369.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 12 umbrellas, 371.6ms
# Speed: 1.0ms preprocess, 371.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 12 umbrellas, 374.2ms
# Speed: 1.2ms preprocess, 374.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 umbrellas, 367.7ms
# Speed: 1.1ms preprocess, 367.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 umbrellas, 429.2ms
# Speed: 1.1ms preprocess, 429.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 umbrellas, 362.5ms
# Speed: 1.0ms preprocess, 362.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 10 umbrellas, 368.8ms
# Speed: 1.0ms preprocess, 368.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 9 umbrellas, 362.3ms
# Speed: 1.0ms preprocess, 362.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 9 umbrellas, 363.5ms
# Speed: 1.0ms preprocess, 363.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 9 umbrellas, 368.3ms
# Speed: 1.1ms preprocess, 368.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 9 umbrellas, 362.2ms
# Speed: 1.0ms preprocess, 362.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 9 umbrellas, 362.8ms
# Speed: 1.0ms preprocess, 362.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 9 umbrellas, 367.9ms
# Speed: 1.1ms preprocess, 367.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 umbrellas, 357.6ms
# Speed: 1.0ms preprocess, 357.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 10 umbrellas, 364.4ms
# Speed: 1.1ms preprocess, 364.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 9 umbrellas, 363.2ms
# Speed: 1.0ms preprocess, 363.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 umbrellas, 361.0ms
# Speed: 1.1ms preprocess, 361.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 6 umbrellas, 368.1ms
# Speed: 1.1ms preprocess, 368.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 5 umbrellas, 362.2ms
# Speed: 0.9ms preprocess, 362.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 umbrellas, 363.1ms
# Speed: 1.1ms preprocess, 363.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 7 umbrellas, 369.5ms
# Speed: 1.0ms preprocess, 369.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 7 umbrellas, 360.5ms
# Speed: 1.1ms preprocess, 360.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 8 umbrellas, 361.0ms
# Speed: 1.0ms preprocess, 361.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 umbrellas, 370.9ms
# Speed: 1.0ms preprocess, 370.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 419.0ms
# Speed: 1.0ms preprocess, 419.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 365.2ms
# Speed: 1.0ms preprocess, 365.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 umbrellas, 367.8ms
# Speed: 1.0ms preprocess, 367.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 1 dog, 9 umbrellas, 366.0ms
# Speed: 1.0ms preprocess, 366.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 9 umbrellas, 374.1ms
# Speed: 1.0ms preprocess, 374.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 9 umbrellas, 361.2ms
# Speed: 1.0ms preprocess, 361.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 8 umbrellas, 368.5ms
# Speed: 1.0ms preprocess, 368.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 376.0ms
# Speed: 1.0ms preprocess, 376.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 363.5ms
# Speed: 1.0ms preprocess, 363.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 umbrellas, 362.9ms
# Speed: 1.0ms preprocess, 362.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 6 umbrellas, 374.7ms
# Speed: 1.0ms preprocess, 374.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 364.8ms
# Speed: 1.0ms preprocess, 364.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 364.9ms
# Speed: 1.1ms preprocess, 364.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 371.0ms
# Speed: 1.0ms preprocess, 371.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 6 umbrellas, 364.3ms
# Speed: 1.1ms preprocess, 364.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 1 frisbee, 399.0ms
# Speed: 1.0ms preprocess, 399.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 1 frisbee, 366.9ms
# Speed: 1.1ms preprocess, 366.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 363.3ms
# Speed: 1.1ms preprocess, 363.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 367.9ms
# Speed: 1.0ms preprocess, 367.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 419.0ms
# Speed: 1.0ms preprocess, 419.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 7 umbrellas, 399.4ms
# Speed: 1.0ms preprocess, 399.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 372.5ms
# Speed: 1.0ms preprocess, 372.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 6 umbrellas, 363.4ms
# Speed: 1.0ms preprocess, 363.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 8 umbrellas, 364.5ms
# Speed: 1.1ms preprocess, 364.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 7 umbrellas, 367.1ms
# Speed: 1.0ms preprocess, 367.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Video processing completed. Check 'output_video.mp4'
